# %% [markdown]
# <a href="https://colab.research.google.com/github/tnounwy21/ML-23-2-/blob/main/%EA%B8%88%EC%9C%B5_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EB%B6%88%EB%9F%AC%EC%98%A4%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U finance-datareader

# %%
import pandas as pd
import FinanceDataReader as fdr

fdr.__version__
# Out:
# '0.9.66'

# %%
fdr.StockListing??
# 국내 주식 시장, 한국거래소 상장 종목 전체 가져오기
df_krx = fdr.StockListing("KRX")
df_krx.shape
# Out:
# (2786, 17)

# %%
df_kospi = fdr.StockListing("KOSPI")
df_kosdaq = fdr.StockListing("KOSDAQ")

# %%
df_kospi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 952 entries, 0 to 951
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Code         952 non-null    object
#  1   ISU_CD       952 non-null    object
#  2   Name         952 non-null    object
#  3   Market       952 non-null    object
#  4   Dept         952 non-null    object
#  5   Close        952 non-null    object
#  6   ChangeCode   952 non-null    object
#  7   Changes      952 non-null    int64
#  8   ChagesRatio  952 non-null    float64
#  9   Open         952 non-null    int64
#  10  High         952 non-null    int64
#  11  Low          952 non-null    int64
#  12  Volume       952 non-null    int64
#  13  Amount       952 non-null    int64
#  14  Marcap       952 non-null    int64
#  15  Stocks       952 non-null    int64
#  16  MarketId     952 non-null    object
# dtypes: float64(1), int64(8), object(8)
# memory usage: 126.6+ KB

# %%
df_kosdaq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1705 entries, 0 to 1704
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Code         1705 non-null   object
#  1   ISU_CD       1705 non-null   object
#  2   Name         1705 non-null   object
#  3   Market       1705 non-null   object
#  4   Dept         1705 non-null   object
#  5   Close        1705 non-null   object
#  6   ChangeCode   1705 non-null   object
#  7   Changes      1705 non-null   int64
#  8   ChagesRatio  1705 non-null   float64
#  9   Open         1705 non-null   int64
#  10  High         1705 non-null   int64
#  11  Low          1705 non-null   int64
#  12  Volume       1705 non-null   int64
#  13  Amount       1705 non-null   int64
#  14  Marcap       1705 non-null   int64
#  15  Stocks       1705 non-null   int64
#  16  MarketId     1705 non-null   object
# dtypes: float64(1), int64(8), object(8)
# memory usage: 226.6+ KB

# %%
df_krx.describe()
# Out:
#             Changes  ChagesRatio           Open           High            Low  \
# count   2786.000000  2786.000000    2786.000000    2786.000000    2786.000000
# mean      60.622398     0.208270   19571.983489   19946.559943   19242.281048
# std     1462.384273     3.336819   48481.113975   49445.675424   47921.623374
# min   -13400.000000   -25.060000       0.000000       0.000000       0.000000
# 25%      -50.000000    -0.790000    2450.000000    2500.000000    2401.250000
# 50%        0.000000     0.000000    6090.000000    6225.000000    6000.000000
# 75%       55.750000     1.020000   15582.500000   15777.500000   15207.500000
# max    34000.000000    30.000000  702000.000000  705000.000000  700000.000000
#
#              Volume        Amount        Marcap        Stocks
# count  2.786000e+03  2.786000e+03  2.786000e+03  2.786000e+03
# mean   5.556880e+05  8.062231e+09  8.879866e+11  4.162263e+07
# std    2.720631e+06  5.170156e+10  9.159936e+12  1.326499e+08
# ...

# %%
df_kospi.head()
# Out:
#      Code        ISU_CD      Name Market Dept   Close ChangeCode  Changes  \
# 0  005930  KR7005930003      삼성전자  KOSPI        73300          1      200
# 1  000660  KR7000660001    SK하이닉스  KOSPI       140000          1     3300
# 2  373220  KR7373220003  LG에너지솔루션  KOSPI       422000          2     -500
# 3  207940  KR7207940008  삼성바이오로직스  KOSPI       703000          1     5000
# 4  005935  KR7005931001     삼성전자우  KOSPI        59300          2     -600
#
#    ChagesRatio    Open    High     Low    Volume         Amount  \
# 0         0.27   73800   74000   73200  15419815  1134484297093
# 1         2.41  137000  140000  137000   5011719   698129501600
# 2        -0.12  426500  431000  422000    341008   144990527500
# 3         0.72  702000  705000  700000     59749    41991591000
# 4        -1.00   59900   60100   59300   1609498    95959015300
#
#             Marcap      Stocks MarketId
# 0  437585060915000  5969782550      STK
# 1  101920331100000   728002365      STK
# ...

# %%
# csv파일로 저장
df_kospi.to_csv("kospi.csv", index=False) #index값을 빼고 저장
# csv로 저장된 파일을 다시 DateFrame으로 읽어서 확인해보기
pd.read_csv("kospi.csv")
# Out:
#        Code        ISU_CD      Name Market  Dept   Close  ChangeCode  Changes  \
# 0    005930  KR7005930003      삼성전자  KOSPI   NaN   73300           1      200
# 1    000660  KR7000660001    SK하이닉스  KOSPI   NaN  140000           1     3300
# 2    373220  KR7373220003  LG에너지솔루션  KOSPI   NaN  422000           2     -500
# 3    207940  KR7207940008  삼성바이오로직스  KOSPI   NaN  703000           1     5000
# 4    005935  KR7005931001     삼성전자우  KOSPI   NaN   59300           2     -600
# ..      ...           ...       ...    ...   ...     ...         ...      ...
# 947  002785  KR7002781003    진흥기업우B  KOSPI   NaN    5020           1       25
# 948  014915  KR7014911002     성문전자우  KOSPI   NaN    6730           2     -350
# 949  001525  KR7001521004       동양우  KOSPI   NaN    6150           1       30
# 950  002787  KR7002782001   진흥기업2우B  KOSPI   NaN   12750           1      160
# 951  001527  KR7001522002     동양2우B  KOSPI   NaN   11800           3        0
#
# ...
